# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk import WordNetLemmatizer
import string

# %%
root_path = "/home/stefan/ioai-prep/kits/essay-gap"

# %% [markdown]
# # Dataset

# %%
stop_words = set(stopwords.words("english"))
to_remove = stop_words | set(string.punctuation)

lemmatizer = WordNetLemmatizer()

def clean_text(text: str):
    text = text.lower()
    tok = nltk.word_tokenize(text)
    tok = [lemmatizer.lemmatize(t) for t in tok if t not in to_remove]
    return ' '.join(tok)

clean_text("Ana has apples.")
# Out:
# 'ana apple'

# %%
train_df = pd.read_csv(f"{root_path}/train.csv")

for col in train_df.select_dtypes(include='object'):
    train_df[col] = train_df[col].apply(clean_text)

train_df.head()
# Out:
#    sampleID                                             before  \
# 0         0  life cycle christmas tree seed 2-metre 7 ft tr...
# 1         1  slope flatter 25 degree steeper 60 degree typi...
# 2         2  workplace conduct `` christmas party '' someti...
# 3         3  chronography 354 illuminated manuscript compil...
# 4         4  english personification christmas first record...
#
#                                                after  \
# 0  one issue farmer face destruction pine tree pe...
# 1  rule thumb slope flat enough hold snow steep e...
# 2  likewise school tafe vocational training unive...
# 3  around 385 feast birth jesus distinct baptism ...
# 4  character maintained late 18th 19th century ch...
#
#                                                opt_0  \
# 0  remaining development tree greatly depends cli...
# 1  1850 book first christmas new england harriet ...
# 2  many people take holiday christmas new year 's...
# 3  eastern inland region country flat well suited...
# 4  sermon 386 gregory nyssa specifically related ...
#
#                                                opt_1  \
# 0  belief divinity jesus lead question `` jesus m...
# 1  latin america iberian peninsula midnight mass ...
# 2  frequency avalanche form given area known retu...
# 3  sermon delivered antioch december 25 c. 386 jo...
# 4  first evidence decorated tree associated chris...
#
#                                                opt_2  \
# 0  essentially recipe brings together traditional...
# 1       steeper slope occur little 15 49 ft snow-ice
# 2  employ on-the-ground physical measurement tech...
# 3  remains one extensive market area united kingd...
# 4  following restoration 1660 father christmas 's...
#
#                                                opt_3  label
# 0                matter debate first christmas stamp      0
# 1  incidence human triggered avalanche normalized...      3
# 2  area around basilica begin crowd light firewor...      0
# 3  cold front leading edge cooler mass air produc...      1
# 4  614 persian sassanid empire supported jewish r...      2

# %%
def common_words_cnt(text1: str, text2: str):
    words1 = set(text1.split())
    words2 = set(text2.split())
    return len(words1 & words2)

common_words_cnt("Ana has apples.", "Maria wants apples.")
# Out:
# 1

# %% [markdown]
# # Submission

# %%
test_df = pd.read_csv(f"{root_path}/test.csv")

for col in train_df.select_dtypes(include="object"):
    test_df[col] = test_df[col].apply(clean_text)

# %%
answers = []

for idx in range(len(test_df)):
    row = test_df.iloc[idx]

    scores = [
        {
            "opt": i,
            "score": common_words_cnt(row["before"], row[f"opt_{i}"])
        } for i in range(4)
    ]

    ans = max(scores, key=lambda x: x["score"])["opt"]
    answers.append(ans)

# %%
submission = pd.DataFrame({"sampleID": test_df["sampleID"], "answer": answers})
submission.head()
# Out:
#    sampleID  answer
# 0       100       0
# 1       101       1
# 2       102       2
# 3       103       0
# 4       104       3

# %%
submission.to_csv("submission.csv", index=False)
